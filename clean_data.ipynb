# %%
import pandas as pd

# %%
df = pd.read_csv('data/census.csv')

# %%
df.columns = df.columns.str.strip()
df.sample(10)
# Out:
#        age          workclass   fnlgt      education  education-num  \
# 7775    36   Self-emp-not-inc  280169   Some-college             10
# 6030    55   Self-emp-not-inc  158315        HS-grad              9
# 7529    64            Private  256466        HS-grad              9
# 8024    22            Private  112847        HS-grad              9
# 834     72                  ?   28929           11th              7
# 7860    30            Private  175856        Masters             14
# 22416   48            Private  176810        HS-grad              9
# 4909    55          Local-gov  177163        Masters             14
# 11920   44          State-gov  136546      Doctorate             16
# 25320   32            Private  419691           12th              8
#
#             marital-status        occupation    relationship  \
# 7775    Married-civ-spouse   Farming-fishing         Husband
# 6030    Married-civ-spouse             Sales         Husband
# 7529    Married-civ-spouse      Tech-support         Husband
# 8024         Never-married      Adm-clerical       Own-child
# 834                Widowed                 ?   Not-in-family
# 7860    Married-civ-spouse    Prof-specialty         Husband
# 22416   Married-civ-spouse     Other-service         Husband
# 4909               Widowed    Prof-specialty       Unmarried
# 11920   Married-civ-spouse    Prof-specialty         Husband
# 25320   Married-civ-spouse             Sales         Husband
#
#                       race      sex  capital-gain  capital-loss  \
# 7775                 White     Male          3456             0
# 6030                 White     Male             0             0
# 7529    Asian-Pac-Islander     Male             0             0
# 8024    Asian-Pac-Islander     Male             0             0
# 834                  White   Female             0             0
# 7860                 White     Male             0             0
# 22416                White     Male             0             0
# 4909                 White   Female           914             0
# 11920                White     Male             0          1902
# 25320                White     Male             0             0
#
#        hours-per-week  native-country  salary
# 7775                8   United-States   <=50K
# 6030               50   United-States    >50K
# 7529               60     Philippines    >50K
# 8024               40   United-States   <=50K
# 834                24   United-States   <=50K
# 7860               38   United-States   <=50K
# 22416              40   United-States   <=50K
# 4909               50   United-States   <=50K
# 11920              40   United-States    >50K
# 25320              40   United-States    >50K

# %%
#Convert Data Types
df['age'] = df['age'].astype(int)
df['fnlgt'] = df['fnlgt'].astype(int)
df['education-num'] = df['education-num'].astype(int)
df['capital-gain'] = df['capital-gain'].astype(int)
df['capital-loss'] = df['capital-loss'].astype(int)
df['hours-per-week'] = df['hours-per-week'].astype(int)

# %%
#Standardize Text Data
string_columns = ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'native-country', 'salary']
for col in string_columns:
    df[col] = df[col].str.strip().str.lower().replace('?', 'undefined')

# %%
df.to_csv('data/census_clean.csv', index=False)
